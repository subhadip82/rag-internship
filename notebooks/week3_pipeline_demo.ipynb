# %% [markdown]
# # Week 3 Document Preparation Pipeline
#
# This notebook demonstrates the Week 3 workflow for loading PDFs, cleaning text, chunking content, and saving JSON/CSV artifacts.

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().resolve().parent))

from run_pipeline import main

main()
